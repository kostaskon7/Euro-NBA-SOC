# %% [markdown]
# ## Euroleague

# %% [markdown]
# #### Played Games

# %%
import requests
import json
import xmltodict
import pandas as pd

# The actual endpoint URL for getting game codes is:
BASE_URL = "https://api-live.euroleague.net/v1/results/" 
SEASON_CODE = "E2025" # Your desired season

params = {
    "seasonCode": SEASON_CODE,
}

# --- TEMPORARY FIX: ADD verify=False ---
try:
    response = requests.get(
        BASE_URL, 
        params=params, 
        timeout=60, 
        verify=False  # <--- THIS IS THE FIX
    )
    
    # Optional: Suppress the InsecureRequestWarning if using verify=False
    requests.packages.urllib3.disable_warnings(requests.packages.urllib3.exceptions.InsecureRequestWarning)
    
    response.raise_for_status() # Check for other HTTP errors (4xx/5xx)
    
    # Process the data just like the EuroLeagueData class does:
    data = xmltodict.parse(response.content)
    game_codes_df = pd.DataFrame(data["results"]["game"])
    
    # print("Successfully retrieved game codes by skipping SSL verification.")
    # print(game_codes_df.head())
    
except requests.exceptions.RequestException as e:
    print(f"Error fetching data (even with verify=False): {e}")

# If successful, you now have the game codes and can continue the schedule logic manually.
# print(game_codes_df)

# game_codes_df = game_codes_df.sort_values("date")
game_codes_df['gamenumber_numeric'] = pd.to_numeric(
    game_codes_df['gamenumber'], 
    errors='coerce'
)

game_codes_df.sort_values(by='gamenumber_numeric', ascending=True)
game_codes_df
# Out:
#     round gameday          date   time gamenumber  gamecode           group  \
# 0      RS       5  Oct 17, 2025  20:45         47  E2025_47  Regular Season
# 1      RS       8  Oct 30, 2025  20:05         73  E2025_73  Regular Season
# 2      RS      10  Nov 11, 2025  17:00         96  E2025_96  Regular Season
# 3      RS       1  Sep 30, 2025  20:45          7   E2025_7  Regular Season
# 4      RS       8  Oct 30, 2025  20:30         72  E2025_72  Regular Season
# ..    ...     ...           ...    ...        ...       ...             ...
# 105    RS       1  Sep 30, 2025  20:30          2   E2025_2  Regular Season
# 106    RS       7  Oct 28, 2025  20:30         61  E2025_61  Regular Season
# 107    RS       9  Nov 07, 2025  18:30         87  E2025_87  Regular Season
# 108    RS       2  Oct 03, 2025  20:00         17  E2025_17  Regular Season
# 109    RS       3  Oct 10, 2025  20:30         28  E2025_28  Regular Season
#
#                      hometeam homecode homescore  \
# 0    BASKONIA VITORIA-GASTEIZ      BAS        79
# 1      MACCABI RAPYD TEL AVIV      TEL        92
# 2            DUBAI BASKETBALL      DUB       102
# 3              VIRTUS BOLOGNA      VIR        74
# 4            FC BAYERN MUNICH      MUN        86
# ..                        ...      ...       ...
# 105  BASKONIA VITORIA-GASTEIZ      BAS        96
# 106  BASKONIA VITORIA-GASTEIZ      BAS        92
# 107     ANADOLU EFES ISTANBUL      IST        93
# 108   LDLC ASVEL VILLEURBANNE      ASV       102
# 109              FC BARCELONA      BAR       108
#
#                                awayteam awaycode awayscore played  \
# 0         PARTIZAN MOZZART BET BELGRADE      PAR        91   true
# 1    CRVENA ZVEZDA MERIDIANBET BELGRADE      RED        99   true
# 2    CRVENA ZVEZDA MERIDIANBET BELGRADE      RED        86   true
# 3                           REAL MADRID      MAD        68   true
# 4                        VIRTUS BOLOGNA      VIR        70   true
# ..                                  ...      ...       ...    ...
# 105                  OLYMPIACOS PIRAEUS      OLY       102   true
# 106                    DUBAI BASKETBALL      DUB        85   true
# 107            EA7 EMPORIO ARMANI MILAN      MIL        97   true
# 108            BASKONIA VITORIA-GASTEIZ      BAS        95   true
# 109                     VALENCIA BASKET      PAM       102   true
#
#      gamenumber_numeric
# 0                    47
# 1                    73
# 2                    96
# 3                     7
# 4                    72
# ..                  ...
# 105                   2
# 106                  61
# 107                  87
# 108                  17
# 109                  28
#
# [110 rows x 15 columns]

# %% [markdown]
# #### Future Games

# %%
import requests
import xmltodict
import pandas as pd

BASE_URL = "https://api-live.euroleague.net/v1/schedules"
SEASON_CODE = "E2025"

params = {"seasonCode": SEASON_CODE}

response = requests.get(BASE_URL, params=params, timeout=60, verify=False)
response.raise_for_status()

data = xmltodict.parse(response.content)

# Correct structure based on your output:
games = pd.DataFrame(data["schedule"]["item"])

# Normalize data types
games["played"] = games["played"].astype(str).str.lower() == "true"

# Convert date to datetime (EuroLeague uses formats like "Sep 30, 2025")
games["date"] = pd.to_datetime(games["date"], errors="coerce")

# Filter to unplayed games (future games)
future_games = games[~games["played"]].copy()

# Sort chronologically
future_games = future_games.sort_values("date")


future_games
# Out:
#     gameday round arenacode                               arenaname  \
# 110      12    RS       AUZ                              LDLC ARENA
# 112      12    RS       AVG  TURKCELL BASKETBALL DEVELOPMENT CENTER
# 113      12    RS       AUM                   TELEKOM CENTER ATHENS
# 117      12    RS       ASX                            UNIPOL FORUM
# 116      12    RS       ATI                          MOVISTAR ARENA
# ..      ...   ...       ...                                     ...
# 374      38    RS       ACA                         COCA-COLA ARENA
# 375      38    RS       AUR                    SALLE GASTON MEDECIN
# 370      38    RS       AMH                         PALAU BLAUGRANA
# 377      38    RS       ATJ                          ZALGIRIO ARENA
# 378      38    RS       AUM                   TELEKOM CENTER ATHENS
#
#     arenacapacity       date startime endtime           group game   gamecode  \
# 110         12523 2025-11-19    20:00   23:30  Regular Season  111  E2025_111
# 112         10000 2025-11-20    18:30   22:00  Regular Season  112  E2025_112
# 113         18500 2025-11-20    20:15   23:45  Regular Season  114  E2025_114
# 117         11200 2025-11-20    20:30   00:00  Regular Season  113  E2025_113
# 116         13109 2025-11-20    20:45   00:15  Regular Season  115  E2025_115
# ..            ...        ...      ...     ...             ...  ...        ...
# 374         13221 2026-04-17    18:00   21:30  Regular Season  378  E2025_378
# 375          5000 2026-04-17    19:30   23:00  Regular Season  377  E2025_377
# 370          7585 2026-04-17    20:30   00:00  Regular Season  379  E2025_379
# 377         15415 2026-04-17    19:00   22:30  Regular Season  380  E2025_380
# 378         18500 2026-04-17    20:15   23:45  Regular Season  376  E2025_376
#
#                        hometeam homecode hometv               awayteam  \
# 110     LDLC ASVEL VILLEURBANNE      ASV    ASV              AS MONACO
# 112       ANADOLU EFES ISTANBUL      IST    EFS           FC BARCELONA
# 113  PANATHINAIKOS AKTOR ATHENS      PAN    PAO       DUBAI BASKETBALL
# 117    EA7 EMPORIO ARMANI MILAN      MIL    EA7    HAPOEL IBI TEL AVIV
# 116                 REAL MADRID      MAD    RMB        ZALGIRIS KAUNAS
# ..                          ...      ...    ...                    ...
# 374            DUBAI BASKETBALL      DUB    DUB        VALENCIA BASKET
# 375                   AS MONACO      MCO    ASM    HAPOEL IBI TEL AVIV
# 370                FC BARCELONA      BAR    BAR       FC BAYERN MUNICH
# 377             ZALGIRIS KAUNAS      ZAL    ZAL       PARIS BASKETBALL
# 378  PANATHINAIKOS AKTOR ATHENS      PAN    PAO  ANADOLU EFES ISTANBUL
#
#     awaycode awaytv confirmeddate confirmedtime  played
# 110      MCO    ASM          true          true   False
# 112      BAR    BAR          true          true   False
# 113      DUB    DUB          true          true   False
# 117      HTA    HTA          true          true   False
# 116      ZAL    ZAL          true          true   False
# ..       ...    ...           ...           ...     ...
# 374      PAM    VBC          true          true   False
# 375      HTA    HTA          true          true   False
# 370      MUN    BAY          true          true   False
# 377      PRS    PBB          true          true   False
# 378      IST    EFS          true          true   False
#
# [270 rows x 20 columns]

# %% [markdown]
# #### Standings

# %%
import requests
import xmltodict
import pandas as pd

BASE_URL = "https://api-live.euroleague.net/v1/standings"
SEASON_CODE = "E2025"

params = {"seasonCode": SEASON_CODE}

response = requests.get(BASE_URL, params=params, timeout=60, verify=False)
response.raise_for_status()

data = xmltodict.parse(response.content)

# Correct root key:
standings_root = data["standings"]

# Group section
g = standings_root["group"]

group_name = g["@name"]
round_name = g["@round"]
game_number = g["@gamenumber"]

teams = g["team"]   # list

rows = []
for t in teams:
    rows.append({
        "group": group_name,
        "round": round_name,
        "gameNumber": int(game_number),
        "teamName": t["name"],
        "teamCode": t["code"],
        "ranking": int(t["ranking"]),
        "totalGames": int(t["totalgames"]),
        "wins": int(t["wins"]),
        "losses": int(t["losses"]),
        "pointsFavour": int(t["ptsfavour"]),
        "pointsAgainst": int(t["ptsagainst"]),
        "difference": int(t["difference"]),
    })

standings_df = pd.DataFrame(rows).sort_values("ranking")
standings_df
# Out:
#              group round  gameNumber                            teamName  \
# 0   Regular Season    RS          11                 Hapoel IBI Tel Aviv
# 1   Regular Season    RS          11  Crvena Zvezda Meridianbet Belgrade
# 2   Regular Season    RS          11                     Zalgiris Kaunas
# 3   Regular Season    RS          11                  Olympiacos Piraeus
# 4   Regular Season    RS          11          Panathinaikos AKTOR Athens
# 5   Regular Season    RS          11                        FC Barcelona
# 6   Regular Season    RS          11            EA7 Emporio Armani Milan
# 7   Regular Season    RS          11                     Valencia Basket
# 8   Regular Season    RS          11                           AS Monaco
# 9   Regular Season    RS          11            Fenerbahce Beko Istanbul
# 10  Regular Season    RS          11                         Real Madrid
# 11  Regular Season    RS          11                    Paris Basketball
# 12  Regular Season    RS          11                    Dubai Basketball
# 13  Regular Season    RS          11                      Virtus Bologna
# 14  Regular Season    RS          11                    FC Bayern Munich
# 15  Regular Season    RS          11               Anadolu Efes Istanbul
# 16  Regular Season    RS          11       Partizan Mozzart Bet Belgrade
# 17  Regular Season    RS          11              Maccabi Rapyd Tel Aviv
# 18  Regular Season    RS          11            Baskonia Vitoria-Gasteiz
# 19  Regular Season    RS          11             LDLC ASVEL Villeurbanne
#
#    teamCode  ranking  totalGames  wins  losses  pointsFavour  pointsAgainst  \
# 0       HTA        1          11     8       3          1000            935
# 1       RED        2          11     8       3           965            902
# 2       ZAL        3          11     7       4           951            876
# 3       OLY        4          11     7       4           945            886
# 4       PAN        5          11     7       4           969            959
# 5       BAR        6          11     7       4           948            947
# 6       MIL        7          11     6       5           890            872
# 7       PAM        8          11     6       5           991            978
# 8       MCO        9          11     6       5           944            931
# 9       ULK       10          11     6       5           870            870
# 10      MAD       11          11     5       6           923            907
# 11      PRS       12          11     5       6           986            977
# 12      DUB       13          11     5       6           949            953
# 13      VIR       14          11     5       6           897            928
# 14      MUN       15          11     5       6           862            895
# 15      IST       16          11     4       7           886            920
# 16      PAR       17          11     4       7           905            946
# 17      TEL       18          11     3       8           969           1015
# 18      BAS       19          11     3       8           950           1015
# 19      ASV       20          11     3       8           855            943
#
#     difference
# 0           65
# 1           63
# 2           75
# 3           59
# 4           10
# 5            1
# 6           18
# 7           13
# 8           13
# 9            0
# 10          16
# 11           9
# 12          -4
# 13         -31
# 14         -33
# 15         -34
# 16         -41
# 17         -46
# 18         -65
# 19         -88

# %% [markdown]
# #### SOS

# %%
import pandas as pd

def compute_strength_of_schedule(standings_df, future_games_df, n_games=None):
    # --- Clean up -------------

    # Ensure date is datetime
    future_games_df["date"] = pd.to_datetime(future_games_df["date"], errors="coerce")

    # Map teamCode → ranking
    rankings = standings_df.set_index("teamCode")["ranking"].to_dict()

    # All EuroLeague team codes in standings
    teams = standings_df["teamCode"].unique()

    results = []

    for team in teams:

        # Team plays as home
        home_games = future_games_df[future_games_df["homecode"] == team].copy()
        home_games["opponent"] = home_games["awaycode"]

        # Team plays as away
        away_games = future_games_df[future_games_df["awaycode"] == team].copy()
        away_games["opponent"] = away_games["homecode"]

        # Combine & sort
        next_games = pd.concat([home_games, away_games]).sort_values("date")

        # Keep only next n games
        next_games = next_games.head(n_games)

        if next_games.empty:
            # Team has no remaining games
            results.append({
                "teamCode": team,
                "teamName": standings_df.loc[standings_df["teamCode"] == team, "teamName"].iloc[0],
                "SOS": None,
                "gamesRemaining": 0,
                "opponents": [],
                "opponentRankings": []
            })
            continue
        
        opp_codes = next_games["opponent"].tolist()
        opp_rankings = [rankings.get(code, None) for code in opp_codes]

        # Compute SOS
        sos = sum(opp_rankings) / len(opp_rankings)

        results.append({
            "teamCode": team,
            "teamName": standings_df.loc[standings_df["teamCode"] == team, "teamName"].iloc[0],
            "SOS": sos,
            "gamesRemaining": len(next_games),
            "opponents": opp_codes,
            "opponentRankings": opp_rankings,
            "gameDates": next_games["date"].tolist(),
            "gameCodes": next_games["gamecode"].tolist()
        })

    sos_df = pd.DataFrame(results).sort_values("SOS")
    return sos_df

# %% [markdown]
# #### SOS 5 Games

# %%
sos_df = compute_strength_of_schedule(standings_df, future_games, n_games=5)
sos_df
# Out:
#    teamCode                            teamName   SOS  gamesRemaining  \
# 11      PRS                    Paris Basketball   7.0               5
# 1       RED  Crvena Zvezda Meridianbet Belgrade   7.2               5
# 15      IST               Anadolu Efes Istanbul   7.4               5
# 3       OLY                  Olympiacos Piraeus   7.6               5
# 7       PAM                     Valencia Basket   8.4               5
# 18      BAS            Baskonia Vitoria-Gasteiz   9.0               5
# 16      PAR       Partizan Mozzart Bet Belgrade   9.2               5
# 10      MAD                         Real Madrid   9.2               5
# 9       ULK            Fenerbahce Beko Istanbul   9.8               5
# 19      ASV             LDLC ASVEL Villeurbanne   9.8               5
# 5       BAR                        FC Barcelona  10.8               5
# 0       HTA                 Hapoel IBI Tel Aviv  10.8               5
# 6       MIL            EA7 Emporio Armani Milan  10.8               5
# 4       PAN          Panathinaikos AKTOR Athens  11.0               5
# 17      TEL              Maccabi Rapyd Tel Aviv  11.4               5
# 13      VIR                      Virtus Bologna  11.8               5
# 12      DUB                    Dubai Basketball  12.8               5
# 2       ZAL                     Zalgiris Kaunas  15.2               5
# 14      MUN                    FC Bayern Munich  15.4               5
# 8       MCO                           AS Monaco  15.4               5
#
#                     opponents      opponentRankings  \
# 11  [OLY, DUB, MCO, ZAL, BAR]      [4, 13, 9, 3, 6]
# 1   [PAM, OLY, BAR, PAR, HTA]      [8, 4, 6, 17, 1]
# 15  [BAR, MCO, MAD, PAM, ZAL]      [6, 9, 11, 8, 3]
# 3   [PRS, RED, ULK, BAR, PAM]     [12, 2, 10, 6, 8]
# 7   [RED, MUN, PAN, IST, OLY]     [2, 15, 5, 16, 4]
# 18  [MUN, ZAL, MIL, MAD, MCO]     [15, 3, 7, 11, 9]
# 16  [ULK, PAN, MUN, RED, VIR]    [10, 5, 15, 2, 14]
# 10  [ZAL, HTA, IST, BAS, MIL]     [3, 1, 16, 19, 7]
# 9   [PAR, VIR, OLY, MCO, PAN]     [17, 14, 4, 9, 5]
# 19  [MCO, BAR, HTA, TEL, MUN]     [9, 6, 1, 18, 15]
# 5   [IST, ASV, RED, OLY, PRS]    [16, 20, 2, 4, 12]
# 0   [MIL, MAD, ASV, VIR, RED]    [7, 11, 20, 14, 2]
# 6   [HTA, TEL, BAS, PAN, MAD]    [1, 18, 19, 5, 11]
# 4   [DUB, PAR, PAM, MIL, ULK]    [13, 17, 8, 7, 10]
# 17  [VIR, MIL, ZAL, ASV, DUB]    [14, 7, 3, 20, 13]
# 13  [TEL, ULK, DUB, HTA, PAR]   [18, 10, 13, 1, 17]
# 12  [PAN, PRS, VIR, MUN, TEL]   [5, 12, 14, 15, 18]
# 2   [MAD, BAS, TEL, PRS, IST]  [11, 19, 18, 12, 16]
# 14  [BAS, PAM, PAR, DUB, ASV]   [19, 8, 17, 13, 20]
# 8   [ASV, IST, PRS, ULK, BAS]  [20, 16, 12, 10, 19]
#
#                                             gameDates  \
# 11  [2025-11-21 00:00:00, 2025-11-25 00:00:00, 202...
# 1   [2025-11-21 00:00:00, 2025-11-26 00:00:00, 202...
# 15  [2025-11-20 00:00:00, 2025-11-26 00:00:00, 202...
# 3   [2025-11-21 00:00:00, 2025-11-26 00:00:00, 202...
# 7   [2025-11-21 00:00:00, 2025-11-25 00:00:00, 202...
# 18  [2025-11-21 00:00:00, 2025-11-25 00:00:00, 202...
# 16  [2025-11-21 00:00:00, 2025-11-25 00:00:00, 202...
# 10  [2025-11-20 00:00:00, 2025-11-25 00:00:00, 202...
# 9   [2025-11-21 00:00:00, 2025-11-25 00:00:00, 202...
# 19  [2025-11-19 00:00:00, 2025-11-26 00:00:00, 202...
# 5   [2025-11-20 00:00:00, 2025-11-26 00:00:00, 202...
# 0   [2025-11-20 00:00:00, 2025-11-25 00:00:00, 202...
# 6   [2025-11-20 00:00:00, 2025-11-26 00:00:00, 202...
# 4   [2025-11-20 00:00:00, 2025-11-25 00:00:00, 202...
# 17  [2025-11-21 00:00:00, 2025-11-26 00:00:00, 202...
# 13  [2025-11-21 00:00:00, 2025-11-25 00:00:00, 202...
# 12  [2025-11-20 00:00:00, 2025-11-25 00:00:00, 202...
# 2   [2025-11-20 00:00:00, 2025-11-25 00:00:00, 202...
# 14  [2025-11-21 00:00:00, 2025-11-25 00:00:00, 202...
# 8   [2025-11-19 00:00:00, 2025-11-26 00:00:00, 202...
#
#                                             gameCodes
# 11  [E2025_117, E2025_121, E2025_131, E2025_144, E...
# 1   [E2025_119, E2025_128, E2025_137, E2025_149, E...
# 15  [E2025_112, E2025_127, E2025_136, E2025_146, E...
# 3   [E2025_117, E2025_128, E2025_134, E2025_148, E...
# 7   [E2025_119, E2025_124, E2025_139, E2025_146, E...
# 18  [E2025_116, E2025_125, E2025_138, E2025_145, E...
# 16  [E2025_118, E2025_123, E2025_132, E2025_149, E...
# 10  [E2025_115, E2025_122, E2025_136, E2025_145, E...
# 9   [E2025_118, E2025_126, E2025_134, E2025_147, E...
# 19  [E2025_111, E2025_129, E2025_133, E2025_141, E...
# 5   [E2025_112, E2025_129, E2025_137, E2025_148, E...
# 0   [E2025_113, E2025_122, E2025_133, E2025_150, E...
# 6   [E2025_113, E2025_130, E2025_138, E2025_143, E...
# 4   [E2025_114, E2025_123, E2025_139, E2025_143, E...
# 17  [E2025_120, E2025_130, E2025_135, E2025_141, E...
# 13  [E2025_120, E2025_126, E2025_140, E2025_150, E...
# 12  [E2025_114, E2025_121, E2025_140, E2025_142, E...
# 2   [E2025_115, E2025_125, E2025_135, E2025_144, E...
# 14  [E2025_116, E2025_124, E2025_132, E2025_142, E...
# 8   [E2025_111, E2025_127, E2025_131, E2025_147, E...

# %% [markdown]
# #### SOS Rest of the season

# %%
sos_df = compute_strength_of_schedule(standings_df, future_games)
sos_df
# Out:
#    teamCode                            teamName        SOS  gamesRemaining  \
# 18      BAS            Baskonia Vitoria-Gasteiz   9.629630              27
# 15      IST               Anadolu Efes Istanbul   9.851852              27
# 11      PRS                    Paris Basketball   9.851852              27
# 4       PAN          Panathinaikos AKTOR Athens   9.925926              27
# 16      PAR       Partizan Mozzart Bet Belgrade   9.925926              27
# 13      VIR                      Virtus Bologna   9.925926              27
# 19      ASV             LDLC ASVEL Villeurbanne  10.037037              27
# 10      MAD                         Real Madrid  10.333333              27
# 9       ULK            Fenerbahce Beko Istanbul  10.407407              27
# 3       OLY                  Olympiacos Piraeus  10.481481              27
# 0       HTA                 Hapoel IBI Tel Aviv  10.592593              27
# 1       RED  Crvena Zvezda Meridianbet Belgrade  10.592593              27
# 17      TEL              Maccabi Rapyd Tel Aviv  10.703704              27
# 6       MIL            EA7 Emporio Armani Milan  10.888889              27
# 12      DUB                    Dubai Basketball  10.925926              27
# 5       BAR                        FC Barcelona  10.962963              27
# 7       PAM                     Valencia Basket  11.037037              27
# 14      MUN                    FC Bayern Munich  11.111111              27
# 2       ZAL                     Zalgiris Kaunas  11.333333              27
# 8       MCO                           AS Monaco  11.481481              27
#
#                                             opponents  \
# 18  [MUN, ZAL, MIL, MAD, MCO, BAR, PAM, ULK, MUN, ...
# 15  [BAR, MCO, MAD, PAM, ZAL, DUB, ASV, RED, PRS, ...
# 11  [OLY, DUB, MCO, ZAL, BAR, MAD, RED, ASV, IST, ...
# 4   [DUB, PAR, PAM, MIL, ULK, HTA, ZAL, OLY, MIL, ...
# 16  [ULK, PAN, MUN, RED, VIR, ZAL, TEL, PAM, MCO, ...
# 13  [TEL, ULK, DUB, HTA, PAR, RED, OLY, MIL, ZAL, ...
# 19  [MCO, BAR, HTA, TEL, MUN, OLY, IST, PRS, MAD, ...
# 10  [ZAL, HTA, IST, BAS, MIL, PRS, MCO, DUB, ASV, ...
# 9   [PAR, VIR, OLY, MCO, PAN, MIL, BAR, BAS, OLY, ...
# 3   [PRS, RED, ULK, BAR, PAM, ASV, VIR, PAN, ULK, ...
# 0   [MIL, MAD, ASV, VIR, RED, PAN, MUN, ZAL, DUB, ...
# 1   [PAM, OLY, BAR, PAR, HTA, VIR, PRS, IST, PAM, ...
# 17  [VIR, MIL, ZAL, ASV, DUB, PAM, PAR, MUN, BAR, ...
# 6   [HTA, TEL, BAS, PAN, MAD, ULK, DUB, VIR, PAN, ...
# 12  [PAN, PRS, VIR, MUN, TEL, IST, MIL, MAD, HTA, ...
# 5   [IST, ASV, RED, OLY, PRS, BAS, ULK, MCO, TEL, ...
# 7   [RED, MUN, PAN, IST, OLY, TEL, BAS, PAR, RED, ...
# 14  [BAS, PAM, PAR, DUB, ASV, MCO, HTA, TEL, BAS, ...
# 2   [MAD, BAS, TEL, PRS, IST, PAR, PAN, HTA, VIR, ...
# 8   [ASV, IST, PRS, ULK, BAS, MUN, MAD, BAR, PAR, ...
#
#                                      opponentRankings  \
# 18  [15, 3, 7, 11, 9, 6, 8, 10, 15, 20, 16, 5, 10,...
# 15  [6, 9, 11, 8, 3, 13, 20, 2, 12, 7, 19, 1, 4, 1...
# 11  [4, 13, 9, 3, 6, 11, 2, 20, 16, 1, 9, 8, 13, 1...
# 4   [13, 17, 8, 7, 10, 1, 3, 4, 7, 14, 15, 19, 18,...
# 16  [10, 5, 15, 2, 14, 3, 18, 8, 9, 6, 4, 15, 1, 7...
# 13  [18, 10, 13, 1, 17, 2, 4, 7, 3, 5, 13, 10, 2, ...
# 19  [9, 6, 1, 18, 15, 4, 16, 12, 11, 19, 1, 3, 6, ...
# 10  [3, 1, 16, 19, 7, 12, 9, 13, 20, 18, 6, 7, 9, ...
# 9   [17, 14, 4, 9, 5, 7, 6, 19, 4, 13, 8, 14, 19, ...
# 3   [12, 2, 10, 6, 8, 20, 14, 5, 10, 15, 17, 18, 1...
# 0   [7, 11, 20, 14, 2, 5, 15, 3, 13, 12, 20, 16, 1...
# 1   [8, 4, 6, 17, 1, 14, 12, 16, 8, 3, 7, 9, 14, 1...
# 17  [14, 7, 3, 20, 13, 8, 17, 15, 6, 11, 3, 4, 5, ...
# 6   [1, 18, 19, 5, 11, 10, 13, 14, 5, 16, 2, 11, 3...
# 12  [5, 12, 14, 15, 18, 16, 7, 11, 1, 10, 14, 6, 1...
# 5   [16, 20, 2, 4, 12, 19, 10, 9, 18, 17, 11, 13, ...
# 7   [2, 15, 5, 16, 4, 18, 19, 17, 2, 9, 10, 12, 15...
# 14  [19, 8, 17, 13, 20, 9, 1, 18, 19, 4, 5, 17, 8,...
# 2   [11, 19, 18, 12, 16, 17, 5, 1, 14, 2, 18, 20, ...
# 8   [20, 16, 12, 10, 19, 15, 11, 6, 17, 8, 12, 2, ...
#
#                                             gameDates  \
# 18  [2025-11-21 00:00:00, 2025-11-25 00:00:00, 202...
# 15  [2025-11-20 00:00:00, 2025-11-26 00:00:00, 202...
# 11  [2025-11-21 00:00:00, 2025-11-25 00:00:00, 202...
# 4   [2025-11-20 00:00:00, 2025-11-25 00:00:00, 202...
# 16  [2025-11-21 00:00:00, 2025-11-25 00:00:00, 202...
# 13  [2025-11-21 00:00:00, 2025-11-25 00:00:00, 202...
# 19  [2025-11-19 00:00:00, 2025-11-26 00:00:00, 202...
# 10  [2025-11-20 00:00:00, 2025-11-25 00:00:00, 202...
# 9   [2025-11-21 00:00:00, 2025-11-25 00:00:00, 202...
# 3   [2025-11-21 00:00:00, 2025-11-26 00:00:00, 202...
# 0   [2025-11-20 00:00:00, 2025-11-25 00:00:00, 202...
# 1   [2025-11-21 00:00:00, 2025-11-26 00:00:00, 202...
# 17  [2025-11-21 00:00:00, 2025-11-26 00:00:00, 202...
# 6   [2025-11-20 00:00:00, 2025-11-26 00:00:00, 202...
# 12  [2025-11-20 00:00:00, 2025-11-25 00:00:00, 202...
# 5   [2025-11-20 00:00:00, 2025-11-26 00:00:00, 202...
# 7   [2025-11-21 00:00:00, 2025-11-25 00:00:00, 202...
# 14  [2025-11-21 00:00:00, 2025-11-25 00:00:00, 202...
# 2   [2025-11-20 00:00:00, 2025-11-25 00:00:00, 202...
# 8   [2025-11-19 00:00:00, 2025-11-26 00:00:00, 202...
#
#                                             gameCodes
# 18  [E2025_116, E2025_125, E2025_138, E2025_145, E...
# 15  [E2025_112, E2025_127, E2025_136, E2025_146, E...
# 11  [E2025_117, E2025_121, E2025_131, E2025_144, E...
# 4   [E2025_114, E2025_123, E2025_139, E2025_143, E...
# 16  [E2025_118, E2025_123, E2025_132, E2025_149, E...
# 13  [E2025_120, E2025_126, E2025_140, E2025_150, E...
# 19  [E2025_111, E2025_129, E2025_133, E2025_141, E...
# 10  [E2025_115, E2025_122, E2025_136, E2025_145, E...
# 9   [E2025_118, E2025_126, E2025_134, E2025_147, E...
# 3   [E2025_117, E2025_128, E2025_134, E2025_148, E...
# 0   [E2025_113, E2025_122, E2025_133, E2025_150, E...
# 1   [E2025_119, E2025_128, E2025_137, E2025_149, E...
# 17  [E2025_120, E2025_130, E2025_135, E2025_141, E...
# 6   [E2025_113, E2025_130, E2025_138, E2025_143, E...
# 12  [E2025_114, E2025_121, E2025_140, E2025_142, E...
# 5   [E2025_112, E2025_129, E2025_137, E2025_148, E...
# 7   [E2025_119, E2025_124, E2025_139, E2025_146, E...
# 14  [E2025_116, E2025_124, E2025_132, E2025_142, E...
# 2   [E2025_115, E2025_125, E2025_135, E2025_144, E...
# 8   [E2025_111, E2025_127, E2025_131, E2025_147, E...

# %%
import requests
import xmltodict
import pandas as pd
import json

# --- SETTINGS ---
SEASON_CODE = "E2025"

# --- FETCH FUTURE GAMES ---
schedule_url = "https://api-live.euroleague.net/v1/schedules"
params = {"seasonCode": SEASON_CODE}

response = requests.get(schedule_url, params=params, timeout=60, verify=False)
response.raise_for_status()

data = xmltodict.parse(response.content)
games_df = pd.DataFrame(data["schedule"]["item"])

# Normalize columns
games_df["played"] = games_df["played"].astype(str).str.lower() == "true"
games_df["date"] = pd.to_datetime(games_df["date"], errors="coerce")

# Keep only unplayed games (future games)
future_games_df = games_df[~games_df["played"]].copy()
future_games_df = future_games_df.sort_values("date")

# Save to JSON
future_games_df.to_json("future_games.json", orient="records", date_format="iso")
print("Saved future_games.json")

# --- FETCH STANDINGS ---
standings_url = "https://api-live.euroleague.net/v1/standings"
response = requests.get(standings_url, params=params, timeout=60, verify=False)
response.raise_for_status()

data = xmltodict.parse(response.content)
standings_root = data["standings"]
group = standings_root["group"]
teams = group["team"]

rows = []
for t in teams:
    rows.append({
        "group": group["@name"],
        "round": group["@round"],
        "gameNumber": int(group["@gamenumber"]),
        "teamName": t["name"],
        "teamCode": t["code"],
        "ranking": int(t["ranking"]),
        "totalGames": int(t["totalgames"]),
        "wins": int(t["wins"]),
        "losses": int(t["losses"]),
        "pointsFavour": int(t["ptsfavour"]),
        "pointsAgainst": int(t["ptsagainst"]),
        "difference": int(t["difference"]),
    })

standings_df = pd.DataFrame(rows).sort_values("ranking")
standings_df.to_json("standings.json", orient="records")
print("Saved standings.json")
# Out:
# Saved future_games.json
# Saved standings.json
